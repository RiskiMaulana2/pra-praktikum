# %%
print("Riski Maulana Achmad") #Nama
print(2605060052) #NIM
print("Magelang,12 November 2005") #ttl
print("Tegalrejo, Magelang") #alamat
print("Laki-laki") # jenis kelamin
print("Sepak bola") #hobi
# Out:
# Riski Maulana Achmad
# 2605060052
# Magelang,12 November 2005
# Tegalrejo, Magelang
# Laki-laki
# Sepak bola
